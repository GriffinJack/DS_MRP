# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('AmesHousing.csv')

# %%
len(data.columns)
# Out:
# 82

# %%
data['Central Air'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
#I am going to make scatter plots for the variables I think have the most corelation with sale price

data.plot.scatter(y="Gr Liv Area", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Gr Liv Area'>

# %%
data.plot.scatter(y="Year Built", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Year Built'>

# %%
data.plot.scatter(y="Lot Frontage", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Lot Frontage'>

# %%
data.plot.scatter(y="Total Bsmt SF", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Total Bsmt SF'>

# %%
data.plot.scatter(y="BsmtFin SF 1", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BsmtFin SF 1'>

# %%
data.plot.scatter(y="Neighborhood", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Neighborhood'>

# %%
data.plot.scatter(y="House Style", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='House Style'>

# %%
data.plot.scatter(y="Overall Qual", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Overall Qual'>

# %%
data.plot.scatter(y="Overall Cond", x="SalePrice")
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Overall Cond'>
